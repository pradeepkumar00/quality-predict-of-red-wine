# %%
import pandas as pd

# %%
data = pd.read_csv('winequality-red.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>],
#        [<AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free sulfur dioxide'}>],
#        [<AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(data, test_size=0.25, random_state = 42)

# %% [markdown]
# len(train_set)

# %%
len(test_set)
# Out:
# 400

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)

# %%
for train_index, test_index in split.split(data ,data['quality']):
    start_train_set = data.iloc[train_index]
    start_test_set = data.iloc[test_index]

# %%
start_train_set['quality'].value_counts()
# Out:
# 5    511
# 6    478
# 7    149
# 4     40
# 8     13
# 3      8
# Name: quality, dtype: int64

# %%
start_test_set['quality'].value_counts()
# Out:
# 5    170
# 6    160
# 7     50
# 4     13
# 8      5
# 3      2
# Name: quality, dtype: int64

# %% [markdown]
# ## Looking for Correlation

# %%
corr_with_quality = data.corr()

# %%
corr_with_quality['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %%
from pandas.plotting  import scatter_matrix

# %%
scatter_matrix(data[["quality","alcohol","sulphates","citric acid","volatile acidity"]], figsize=(20, 10))
# Out:
# array([[<AxesSubplot:xlabel='quality', ylabel='quality'>,
#         <AxesSubplot:xlabel='alcohol', ylabel='quality'>,
#         <AxesSubplot:xlabel='sulphates', ylabel='quality'>,
#         <AxesSubplot:xlabel='citric acid', ylabel='quality'>,
#         <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>],
#        [<AxesSubplot:xlabel='quality', ylabel='alcohol'>,
#         <AxesSubplot:xlabel='alcohol', ylabel='alcohol'>,
#         <AxesSubplot:xlabel='sulphates', ylabel='alcohol'>,
#         <AxesSubplot:xlabel='citric acid', ylabel='alcohol'>,
#         <AxesSubplot:xlabel='volatile acidity', ylabel='alcohol'>],
#        [<AxesSubplot:xlabel='quality', ylabel='sulphates'>,
#         <AxesSubplot:xlabel='alcohol', ylabel='sulphates'>,
#         <AxesSubplot:xlabel='sulphates', ylabel='sulphates'>,
#         <AxesSubplot:xlabel='citric acid', ylabel='sulphates'>,
#         <AxesSubplot:xlabel='volatile acidity', ylabel='sulphates'>],
# ...

# %% [markdown]
# ## Creating pipeline

# %%
train_set_tr = train_set.drop("quality", axis=1)
train_set_labels = train_set['quality'].copy()

# %% [markdown]
# ## Choose desired model

# %% [markdown]
# 1st model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(train_set_tr, train_set_labels)
# Out:
# LinearRegression()

# %%
some_data = train_set_tr.iloc[:5]
some_lables = train_set_labels.iloc[:5]
some_lables
# Out:
# 582     5
# 626     5
# 1030    7
# 620     5
# 490     6
# Name: quality, dtype: int64

# %%
predict_value = model.predict(some_data)

# %%
predict_value
# Out:
# array([5.23381934, 5.04148093, 5.8674267 , 5.08232226, 5.46492836])

# %%
list(some_lables)
# Out:
# [5, 5, 7, 5, 6]

# %% [markdown]
# ## Evaluating model

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
data_predictions = model.predict(train_set_tr)
mse = mean_squared_error(train_set_labels, data_predictions)
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.6537726276403218

# %% [markdown]
# 2nd model

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(train_set_tr, train_set_labels)
# Out:
# DecisionTreeRegressor()

# %%
predict_val_dtree = model.predict(some_data)

# %%
predict_val_dtree
# Out:
# array([5., 5., 7., 5., 6.])

# %%
list(some_lables)
# Out:
# [5, 5, 7, 5, 6]

# %% [markdown]
# # Cross Validation for Decision tree

# %%
from sklearn.model_selection import cross_val_score
val_sc = cross_val_score(model, train_set_tr, train_set_labels, scoring ="neg_mean_squared_error", cv=10)
rmse_sc = np.sqrt(-val_sc)

# %%
rmse_sc
# Out:
# array([0.88034084, 0.67082039, 0.87082337, 0.77459667, 0.90829511,
#        0.74161985, 0.85634884, 0.90369611, 0.67082039, 0.80960619])

# %%
def print_scores(scores):
    print("Scores: ", scores)
    print("Mean: ", scores.mean())
    print("Standard deviation: ", scores.std())

# %%
print_scores(rmse_sc)
# Out:
# Scores:  [0.88034084 0.67082039 0.87082337 0.77459667 0.90829511 0.74161985
#  0.85634884 0.90369611 0.67082039 0.80960619]
# Mean:  0.8086967762857599
# Standard deviation:  0.0859597338627084

# %% [markdown]
# #Linear_regrassion is better than Decision tree

# %% [markdown]
# 3rd Model

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(train_set_tr, train_set_labels)
# Out:
# RandomForestRegressor()

# %%
predict_val_rfr = model.predict(some_data)

# %%
predict_val_rfr
# Out:
# array([4.98, 5.  , 6.6 , 5.04, 5.91])

# %%
list(some_lables)
# Out:
# [5, 5, 7, 5, 6]

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
data_predictions_rfr = model.predict(train_set_tr)
mse = mean_squared_error(train_set_labels, data_predictions_rfr)
rmse_rfr = np.sqrt(mse)

# %%
rmse_rfr
# Out:
# 0.22462126404287028

# %%
#3rd Random_forest_modelis best in three

# %% [markdown]
# ## Save the model

# %%
from joblib import dump, load
dump(model, 'red_wine.joblib')
# Out:
# ['red_wine.joblib']

# %%
test_set_data = test_set.drop("quality", axis=1)
test_set_lables = test_set["quality"].copy()
final_predication = model.predict(test_set_data)
final_mse = mean_squared_error(test_set_labels, final_predication)
final_rmse = np.sqrt(final_mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b8077c9f9ed1> in <module>
#       2 test_set_lables = test_set["quality"].copy()
#       3 final_predication = model.predict(test_set_data)
# ----> 4 final_mse = mean_squared_error(test_set_labels, final_predication)
#       5 final_rmse = np.sqrt(final_mse)
#
# NameError: name 'test_set_labels' is not defined
